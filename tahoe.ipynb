# %%
import os
import io
import pandas as pd
import scanpy as sc
import pyarrow.dataset as ds
import gcsfs

# %%
fs = gcsfs.GCSFileSystem()

# %%
gcp_base_path = "gs://arc-ctc-tahoe100/2025-02-25/"

# %%
infile = os.path.join(gcp_base_path, 'metadata', 'sample_metadata.parquet')

# %%
sample_metadata = ds.dataset(infile, filesystem=fs, format="parquet").head(3).to_pandas()
sample_metadata
# Out:
#      sample   plate  mean_gene_count  mean_tscp_count  mean_mread_count  \
# 0  smp_1495  plate1             1354             2027              2444
# 1  smp_1496  plate1             1404             2226              2691
# 2  smp_1497  plate1             1205             1859              2246
#
#    mean_pcnt_mito          drug               drugname_drugconc
# 0               0  Infigratinib  [('Infigratinib', 0.05, 'uM')]
# 1               0  Erdafitinib   [('Erdafitinib ', 0.05, 'uM')]
# 2               0    Everolimus    [('Everolimus', 0.05, 'uM')]

# %%
# select certain columns and row filtering
columns_to_read = ['sample', 'plate', 'mean_gene_count']  # Specify the columns you need
dataset = ds.dataset(infile, filesystem=fs, format="parquet")
sample_metadata = dataset.to_table(filter=(ds.field('mean_gene_count') > 2000), columns=columns_to_read).to_pandas()
sample_metadata
# Out:
#       sample    plate  mean_gene_count
# 0   smp_1598   plate2             2196
# 1   smp_1604   plate2             2039
# 2   smp_1605   plate2             2043
# 3   smp_2044   plate6             2156
# 4   smp_2046   plate6             2073
# 5   smp_2054   plate6             2036
# 6   smp_2056   plate6             2059
# 7   smp_2060   plate6             2095
# 8   smp_2066   plate6             2230
# 9   smp_2067   plate6             2193
# 10  smp_2624  plate12             2115

# %%
# get the number of samples
columns_to_read = ["sample"]  # Specify the columns you need
dataset = ds.dataset(infile, filesystem=fs, format="parquet")
sample_count = dataset.to_table(columns=columns_to_read).to_pandas()["sample"].nunique()
print(f"Number of samples: {sample_count}")
# Out:
# Number of samples: 1344

# %%
# set the path to the obs_metadata file
infile = os.path.join(gcp_base_path, 'metadata', 'obs_metadata.parquet')

# %%
# get samples per plate
columns_to_read = ["plate", "sample"]  # Specify the columns you need
dataset = ds.dataset(infile, filesystem=fs, format="parquet")
samples_per_plate = dataset.to_table(columns=columns_to_read).to_pandas().groupby("plate").size()
samples_per_plate
# Out:
# plate
# plate1      5481420
# plate10     8044908
# plate11     7435869
# plate12    10487057
# plate13     8501658
# plate14     6518806
# plate2      8064658
# plate3      4705402
# plate4      7004356
# plate5      6419498
# plate6      7545393
# plate7      5692117
# plate8      8880979
# plate9      5866669
# dtype: int64

# %%
# read a subset of the metadata
obs_metadata = ds.dataset(infile, filesystem=fs, format="parquet").head(100000).to_pandas()
obs_metadata
# Out:
#          plate   BARCODE_SUB_LIB_ID    sample  gene_count  tscp_count  \
# 0      plate10  01_001_001-lib_1681  smp_2359        1379        2172
# 1      plate10  01_002_149-lib_1681  smp_2359         975        1256
# 2      plate10  01_003_052-lib_1681  smp_2359         865        1239
# 3      plate10  01_003_090-lib_1681  smp_2359         393         484
# 4      plate10  01_003_093-lib_1681  smp_2359        2657        5325
# ...        ...                  ...       ...         ...         ...
# 99995  plate10  72_141_112-lib_1682  smp_2430        1481        2171
# 99996  plate10  72_141_131-lib_1682  smp_2430        1430        2119
# 99997  plate10  72_141_184-lib_1682  smp_2430         827        1044
# 99998  plate10  72_142_157-lib_1682  smp_2430         875        1153
# 99999  plate10  72_142_175-lib_1682  smp_2430        1183        1707
#
#        mread_count                           drugname_drugconc  \
# 0             2559  [('Bestatin (hydrochloride)', 0.05, 'uM')]
# 1             1470  [('Bestatin (hydrochloride)', 0.05, 'uM')]
# 2             1446  [('Bestatin (hydrochloride)', 0.05, 'uM')]
# 3              559  [('Bestatin (hydrochloride)', 0.05, 'uM')]
# 4             6269  [('Bestatin (hydrochloride)', 0.05, 'uM')]
# ...            ...                                         ...
# 99995         2559                [('γ-Oryzanol', 0.05, 'uM')]
# 99996         2496                [('γ-Oryzanol', 0.05, 'uM')]
# 99997         1201                [('γ-Oryzanol', 0.05, 'uM')]
# 99998         1333                [('γ-Oryzanol', 0.05, 'uM')]
# 99999         2014                [('γ-Oryzanol', 0.05, 'uM')]
#
#                            drug  cell_line sublibrary     BARCODE  pcnt_mito  \
# 0      Bestatin (hydrochloride)  CVCL_1478   lib_1681  01_001_001   0.029926
# 1      Bestatin (hydrochloride)  CVCL_0459   lib_1681  01_002_149   0.026274
# 2      Bestatin (hydrochloride)  CVCL_C466   lib_1681  01_003_052   0.033898
# 3      Bestatin (hydrochloride)  CVCL_1724   lib_1681  01_003_090   0.037190
# 4      Bestatin (hydrochloride)  CVCL_1285   lib_1681  01_003_093   0.017465
# ...                         ...        ...        ...         ...        ...
# 99995                γ-Oryzanol  CVCL_0366   lib_1682  72_141_112   0.042837
# 99996                γ-Oryzanol  CVCL_0371   lib_1682  72_141_131   0.074563
# 99997                γ-Oryzanol  CVCL_1693   lib_1682  72_141_184   0.045019
# 99998                γ-Oryzanol  CVCL_0320   lib_1682  72_142_157   0.071119
# 99999                γ-Oryzanol  CVCL_0480   lib_1682  72_142_175   0.056825
#
#         S_score  G2M_score phase pass_filter   cell_name
# 0     -0.229665  -0.190110    G1        full   NCI-H1573
# 1     -0.167578  -0.132784    G1        full    NCI-H460
# 2     -0.200957  -0.161538    G1        full  hTERT-HPNE
# 3     -0.052746  -0.076190    G1     minimal        SW48
# 4     -0.636364  -0.614103    G1        full       HOP62
# ...         ...        ...   ...         ...         ...
# 99995  0.000000  -0.100386     S        full     SNU-423
# 99996 -0.009524  -0.028340    G1        full    KATO III
# 99997 -0.028571  -0.057324    G1        full      SHP-77
# 99998 -0.061905  -0.042970    G1        full       HT-29
# 99999 -0.123810   0.039014   G2M        full      PANC-1
#
# [100000 rows x 17 columns]

# %%
# sample count
obs_metadata["sample"].nunique()
# Out:
# 96

# %%
# gene count distribution
pd.options.display.float_format = '{:.0f}'.format
obs_metadata["gene_count"].describe()
# Out:
# count   100000
# mean      1382
# std        735
# min        268
# 25%        896
# 50%       1209
# 75%       1661
# max       9395
# Name: gene_count, dtype: float64

# %%
# tscp (UMI) count distribution
pd.options.display.float_format = '{:.0f}'.format
obs_metadata["tscp_count"].describe()
# Out:
# count   100000
# mean      2214
# std       1833
# min        392
# 25%       1230
# 50%       1748
# 75%       2583
# max      54006
# Name: tscp_count, dtype: float64

# %%
# set the path to the plate metadata file
infile = "gs://arc-ctc-tahoe100/2025-02-25/tutorial/plate3_2k-obs.h5ad"
infile = "gs://arc-ctc-tahoe100/2025-02-25/h5ad/plate3_filt_Vevo_Tahoe100M_WServicesFrom_ParseGigalab.h5ad"
infile = 'plate14_filt_Vevo_Tahoe100M_WServicesFrom_ParseGigalab.h5ad'
#infile = 'plate3_CVCL_0023.h5ad'
infile
# Out:
# 'plate14_filt_Vevo_Tahoe100M_WServicesFrom_ParseGigalab.h5ad'

# %%
import timeit
from datetime import timedelta

# read in the h5ad file
t_0 = timeit.default_timer()
#with fs.open(infile, 'rb') as f:
#with open(infile, 'rb') as f:
#adata = sc.read_h5ad(f,backed='r+')
adata = sc.read_h5ad(infile)
#adata = sc.read_h5ad(infile,backed='r')
#adata = sc.read_h5ad(infile)
t_1 = timeit.default_timer()
elapsed_time = round((t_1 - t_0), 3)
print(f"Elapsed time: {elapsed_time} s")
adata
# Out:
# Elapsed time: 316.571 s
# AnnData object with n_obs × n_vars = 6518806 × 62710
#     obs: 'sample', 'gene_count', 'tscp_count', 'mread_count', 'drugname_drugconc', 'drug', 'cell_line', 'sublibrary', 'BARCODE', 'pcnt_mito', 'S_score', 'G2M_score', 'phase', 'pass_filter', 'cell_name', 'plate'

# %%
cell_lines = list(set(adata.obs['cell_line']))
print(cell_lines)
plate = list(set(adata.obs['plate']))[0]
print(plate)
# Out:
# ['CVCL_0320', 'CVCL_0023', 'CVCL_1666', 'CVCL_1635', 'CVCL_1550', 'CVCL_0399', 'CVCL_0480', 'CVCL_0099', 'CVCL_1285', 'CVCL_0028', 'CVCL_1716', 'CVCL_1478', 'CVCL_0152', 'CVCL_1731', 'CVCL_0131', 'CVCL_1577', 'CVCL_1531', 'CVCL_1239', 'CVCL_0371', 'CVCL_1571', 'CVCL_0332', 'CVCL_1724', 'CVCL_1125', 'CVCL_0428', 'CVCL_0218', 'CVCL_1056', 'CVCL_1098', 'CVCL_0366', 'CVCL_0179', 'CVCL_0459', 'CVCL_0397', 'CVCL_C466', 'CVCL_1055', 'CVCL_1547', 'CVCL_0504', 'CVCL_0293', 'CVCL_0334', 'CVCL_1097', 'CVCL_0359', 'CVCL_1119', 'CVCL_1717', 'CVCL_0292', 'CVCL_0069', 'CVCL_1381', 'CVCL_1693', 'CVCL_0546', 'CVCL_1517', 'CVCL_1715', 'CVCL_1495', 'CVCL_1094']
# plate14

# %%
for i,cell_line in enumerate(cell_lines):
    adata1 = adata[adata.obs['cell_line']==cell_line,:]
    print(i,'/',len(cell_lines),cell_line,adata1)
    #sc.pl.scatter(adata1,x="S_score",y="G2M_score",color="drug")
    adata1.write(plate+'_'+cell_line+'.h5ad',compression='gzip')
# Out:
# 0 / 50 CVCL_0320 View of AnnData object with n_obs × n_vars = 162610 × 62710
#     obs: 'sample', 'gene_count', 'tscp_count', 'mread_count', 'drugname_drugconc', 'drug', 'cell_line', 'sublibrary', 'BARCODE', 'pcnt_mito', 'S_score', 'G2M_score', 'phase', 'pass_filter', 'cell_name', 'plate'
# 1 / 50 CVCL_0023 View of AnnData object with n_obs × n_vars = 182446 × 62710
#     obs: 'sample', 'gene_count', 'tscp_count', 'mread_count', 'drugname_drugconc', 'drug', 'cell_line', 'sublibrary', 'BARCODE', 'pcnt_mito', 'S_score', 'G2M_score', 'phase', 'pass_filter', 'cell_name', 'plate'
# 2 / 50 CVCL_1666 View of AnnData object with n_obs × n_vars = 100623 × 62710
#     obs: 'sample', 'gene_count', 'tscp_count', 'mread_count', 'drugname_drugconc', 'drug', 'cell_line', 'sublibrary', 'BARCODE', 'pcnt_mito', 'S_score', 'G2M_score', 'phase', 'pass_filter', 'cell_name', 'plate'
# 3 / 50 CVCL_1635 View of AnnData object with n_obs × n_vars = 113097 × 62710
#     obs: 'sample', 'gene_count', 'tscp_count', 'mread_count', 'drugname_drugconc', 'drug', 'cell_line', 'sublibrary', 'BARCODE', 'pcnt_mito', 'S_score', 'G2M_score', 'phase', 'pass_filter', 'cell_name', 'plate'
# 4 / 50 CVCL_1550 View of AnnData object with n_obs × n_vars = 147438 × 62710
#     obs: 'sample', 'gene_count', 'tscp_count', 'mread_count', 'drugname_drugconc', 'drug', 'cell_line', 'sublibrary', 'BARCODE', 'pcnt_mito', 'S_score', 'G2M_score', 'phase', 'pass_filter', 'cell_name', 'plate'
# 5 / 50 CVCL_0399 View of AnnData object with n_obs × n_vars = 267380 × 62710
#     obs: 'sample', 'gene_count', 'tscp_count', 'mread_count', 'drugname_drugconc', 'drug', 'cell_line', 'sublibrary', 'BARCODE', 'pcnt_mito', 'S_score', 'G2M_score', 'phase', 'pass_filter', 'cell_name', 'plate'
# 6 / 50 CVCL_0480 View of AnnData object with n_obs × n_vars = 216753 × 62710
#     obs: 'sample', 'gene_count', 'tscp_count', 'mread_count', 'drugname_drugconc', 'drug', 'cell_line', 'sublibrary', 'BARCODE', 'pcnt_mito', 'S_score', 'G2M_score', 'phase', 'pass_filter', 'cell_name', 'plate'
# 7 / 50 CVCL_0099 View of AnnData object with n_obs × n_vars = 52483 × 62710
#     obs: 'sample', 'gene_count', 'tscp_count', 'mread_count', 'drugname_drugconc', 'drug', 'cell_line', 'sublibrary', 'BARCODE', 'pcnt_mito', 'S_score', 'G2M_score', 'phase', 'pass_filter', 'cell_name', 'plate'
# 8 / 50 CVCL_1285 View of AnnData object with n_obs × n_vars = 216464 × 62710
#     obs: 'sample', 'gene_count', 'tscp_count', 'mread_count', 'drugname_drugconc', 'drug', 'cell_line', 'sublibrary', 'BARCODE', 'pcnt_mito', 'S_score', 'G2M_score', 'phase', 'pass_filter', 'cell_name', 'plate'
# 9 / 50 CVCL_0028 View of AnnData object with n_obs × n_vars = 40777 × 62710
#     obs: 'sample', 'gene_count', 'tscp_count', 'mread_count', 'drugname_drugconc', 'drug', 'cell_line', 'sublibrary', 'BARCODE', 'pcnt_mito', 'S_score', 'G2M_score', 'phase', 'pass_filter', 'cell_name', 'plate'
# 10 / 50 CVCL_1716 View of AnnData object with n_obs × n_vars = 18540 × 62710
#     obs: 'sample', 'gene_count', 'tscp_count', 'mread_count', 'drugname_drugconc', 'drug', 'cell_line', 'sublibrary', 'BARCODE', 'pcnt_mito', 'S_score', 'G2M_score', 'phase', 'pass_filter', 'cell_name', 'plate'
# 11 / 50 CVCL_1478 View of AnnData object with n_obs × n_vars = 163643 × 62710
#     obs: 'sample', 'gene_count', 'tscp_count', 'mread_count', 'drugname_drugconc', 'drug', 'cell_line', 'sublibrary', 'BARCODE', 'pcnt_mito', 'S_score', 'G2M_score', 'phase', 'pass_filter', 'cell_name', 'plate'
# 12 / 50 CVCL_0152 View of AnnData object with n_obs × n_vars = 187899 × 62710
#     obs: 'sample', 'gene_count', 'tscp_count', 'mread_count', 'drugname_drugconc', 'drug', 'cell_line', 'sublibrary', 'BARCODE', 'pcnt_mito', 'S_score', 'G2M_score', 'phase', 'pass_filter', 'cell_name', 'plate'
# 13 / 50 CVCL_1731 View of AnnData object with n_obs × n_vars = 119521 × 62710
#     obs: 'sample', 'gene_count', 'tscp_count', 'mread_count', 'drugname_drugconc', 'drug', 'cell_line', 'sublibrary', 'BARCODE', 'pcnt_mito', 'S_score', 'G2M_score', 'phase', 'pass_filter', 'cell_name', 'plate'
# 14 / 50 CVCL_0131 View of AnnData object with n_obs × n_vars = 193855 × 62710
#     obs: 'sample', 'gene_count', 'tscp_count', 'mread_count', 'drugname_drugconc', 'drug', 'cell_line', 'sublibrary', 'BARCODE', 'pcnt_mito', 'S_score', 'G2M_score', 'phase', 'pass_filter', 'cell_name', 'plate'
# 15 / 50 CVCL_1577 View of AnnData object with n_obs × n_vars = 8872 × 62710
#     obs: 'sample', 'gene_count', 'tscp_count', 'mread_count', 'drugname_drugconc', 'drug', 'cell_line', 'sublibrary', 'BARCODE', 'pcnt_mito', 'S_score', 'G2M_score', 'phase', 'pass_filter', 'cell_name', 'plate'
# 16 / 50 CVCL_1531 View of AnnData object with n_obs × n_vars = 3158 × 62710
#     obs: 'sample', 'gene_count', 'tscp_count', 'mread_count', 'drugname_drugconc', 'drug', 'cell_line', 'sublibrary', 'BARCODE', 'pcnt_mito', 'S_score', 'G2M_score', 'phase', 'pass_filter', 'cell_name', 'plate'
# 17 / 50 CVCL_1239 View of AnnData object with n_obs × n_vars = 64039 × 62710
#     obs: 'sample', 'gene_count', 'tscp_count', 'mread_count', 'drugname_drugconc', 'drug', 'cell_line', 'sublibrary', 'BARCODE', 'pcnt_mito', 'S_score', 'G2M_score', 'phase', 'pass_filter', 'cell_name', 'plate'
# 18 / 50 CVCL_0371 View of AnnData object with n_obs × n_vars = 167363 × 62710
#     obs: 'sample', 'gene_count', 'tscp_count', 'mread_count', 'drugname_drugconc', 'drug', 'cell_line', 'sublibrary', 'BARCODE', 'pcnt_mito', 'S_score', 'G2M_score', 'phase', 'pass_filter', 'cell_name', 'plate'
# 19 / 50 CVCL_1571 View of AnnData object with n_obs × n_vars = 2090 × 62710
#     obs: 'sample', 'gene_count', 'tscp_count', 'mread_count', 'drugname_drugconc', 'drug', 'cell_line', 'sublibrary', 'BARCODE', 'pcnt_mito', 'S_score', 'G2M_score', 'phase', 'pass_filter', 'cell_name', 'plate'
# 20 / 50 CVCL_0332 View of AnnData object with n_obs × n_vars = 100572 × 62710
#     obs: 'sample', 'gene_count', 'tscp_count', 'mread_count', 'drugname_drugconc', 'drug', 'cell_line', 'sublibrary', 'BARCODE', 'pcnt_mito', 'S_score', 'G2M_score', 'phase', 'pass_filter', 'cell_name', 'plate'
# 21 / 50 CVCL_1724 View of AnnData object with n_obs × n_vars = 84655 × 62710
#     obs: 'sample', 'gene_count', 'tscp_count', 'mread_count', 'drugname_drugconc', 'drug', 'cell_line', 'sublibrary', 'BARCODE', 'pcnt_mito', 'S_score', 'G2M_score', 'phase', 'pass_filter', 'cell_name', 'plate'
# 22 / 50 CVCL_1125 View of AnnData object with n_obs × n_vars = 29731 × 62710
#     obs: 'sample', 'gene_count', 'tscp_count', 'mread_count', 'drugname_drugconc', 'drug', 'cell_line', 'sublibrary', 'BARCODE', 'pcnt_mito', 'S_score', 'G2M_score', 'phase', 'pass_filter', 'cell_name', 'plate'
# 23 / 50 CVCL_0428 View of AnnData object with n_obs × n_vars = 70299 × 62710
#     obs: 'sample', 'gene_count', 'tscp_count', 'mread_count', 'drugname_drugconc', 'drug', 'cell_line', 'sublibrary', 'BARCODE', 'pcnt_mito', 'S_score', 'G2M_score', 'phase', 'pass_filter', 'cell_name', 'plate'
# 24 / 50 CVCL_0218 View of AnnData object with n_obs × n_vars = 115264 × 62710
#     obs: 'sample', 'gene_count', 'tscp_count', 'mread_count', 'drugname_drugconc', 'drug', 'cell_line', 'sublibrary', 'BARCODE', 'pcnt_mito', 'S_score', 'G2M_score', 'phase', 'pass_filter', 'cell_name', 'plate'
# 25 / 50 CVCL_1056 View of AnnData object with n_obs × n_vars = 171832 × 62710
#     obs: 'sample', 'gene_count', 'tscp_count', 'mread_count', 'drugname_drugconc', 'drug', 'cell_line', 'sublibrary', 'BARCODE', 'pcnt_mito', 'S_score', 'G2M_score', 'phase', 'pass_filter', 'cell_name', 'plate'
# 26 / 50 CVCL_1098 View of AnnData object with n_obs × n_vars = 138398 × 62710
#     obs: 'sample', 'gene_count', 'tscp_count', 'mread_count', 'drugname_drugconc', 'drug', 'cell_line', 'sublibrary', 'BARCODE', 'pcnt_mito', 'S_score', 'G2M_score', 'phase', 'pass_filter', 'cell_name', 'plate'
# 27 / 50 CVCL_0366 View of AnnData object with n_obs × n_vars = 127734 × 62710
#     obs: 'sample', 'gene_count', 'tscp_count', 'mread_count', 'drugname_drugconc', 'drug', 'cell_line', 'sublibrary', 'BARCODE', 'pcnt_mito', 'S_score', 'G2M_score', 'phase', 'pass_filter', 'cell_name', 'plate'
# 28 / 50 CVCL_0179 View of AnnData object with n_obs × n_vars = 105116 × 62710
#     obs: 'sample', 'gene_count', 'tscp_count', 'mread_count', 'drugname_drugconc', 'drug', 'cell_line', 'sublibrary', 'BARCODE', 'pcnt_mito', 'S_score', 'G2M_score', 'phase', 'pass_filter', 'cell_name', 'plate'
# 29 / 50 CVCL_0459 View of AnnData object with n_obs × n_vars = 376950 × 62710
#     obs: 'sample', 'gene_count', 'tscp_count', 'mread_count', 'drugname_drugconc', 'drug', 'cell_line', 'sublibrary', 'BARCODE', 'pcnt_mito', 'S_score', 'G2M_score', 'phase', 'pass_filter', 'cell_name', 'plate'
# 30 / 50 CVCL_0397 View of AnnData object with n_obs × n_vars = 147485 × 62710
#     obs: 'sample', 'gene_count', 'tscp_count', 'mread_count', 'drugname_drugconc', 'drug', 'cell_line', 'sublibrary', 'BARCODE', 'pcnt_mito', 'S_score', 'G2M_score', 'phase', 'pass_filter', 'cell_name', 'plate'
# 31 / 50 CVCL_C466 View of AnnData object with n_obs × n_vars = 132675 × 62710
#     obs: 'sample', 'gene_count', 'tscp_count', 'mread_count', 'drugname_drugconc', 'drug', 'cell_line', 'sublibrary', 'BARCODE', 'pcnt_mito', 'S_score', 'G2M_score', 'phase', 'pass_filter', 'cell_name', 'plate'
# 32 / 50 CVCL_1055 View of AnnData object with n_obs × n_vars = 88129 × 62710
#     obs: 'sample', 'gene_count', 'tscp_count', 'mread_count', 'drugname_drugconc', 'drug', 'cell_line', 'sublibrary', 'BARCODE', 'pcnt_mito', 'S_score', 'G2M_score', 'phase', 'pass_filter', 'cell_name', 'plate'
# 33 / 50 CVCL_1547 View of AnnData object with n_obs × n_vars = 136099 × 62710
#     obs: 'sample', 'gene_count', 'tscp_count', 'mread_count', 'drugname_drugconc', 'drug', 'cell_line', 'sublibrary', 'BARCODE', 'pcnt_mito', 'S_score', 'G2M_score', 'phase', 'pass_filter', 'cell_name', 'plate'
# 34 / 50 CVCL_0504 View of AnnData object with n_obs × n_vars = 136224 × 62710
#     obs: 'sample', 'gene_count', 'tscp_count', 'mread_count', 'drugname_drugconc', 'drug', 'cell_line', 'sublibrary', 'BARCODE', 'pcnt_mito', 'S_score', 'G2M_score', 'phase', 'pass_filter', 'cell_name', 'plate'
# 35 / 50 CVCL_0293 View of AnnData object with n_obs × n_vars = 236414 × 62710
#     obs: 'sample', 'gene_count', 'tscp_count', 'mread_count', 'drugname_drugconc', 'drug', 'cell_line', 'sublibrary', 'BARCODE', 'pcnt_mito', 'S_score', 'G2M_score', 'phase', 'pass_filter', 'cell_name', 'plate'
# 36 / 50 CVCL_0334 View of AnnData object with n_obs × n_vars = 78710 × 62710
#     obs: 'sample', 'gene_count', 'tscp_count', 'mread_count', 'drugname_drugconc', 'drug', 'cell_line', 'sublibrary', 'BARCODE', 'pcnt_mito', 'S_score', 'G2M_score', 'phase', 'pass_filter', 'cell_name', 'plate'
# 37 / 50 CVCL_1097 View of AnnData object with n_obs × n_vars = 160195 × 62710
#     obs: 'sample', 'gene_count', 'tscp_count', 'mread_count', 'drugname_drugconc', 'drug', 'cell_line', 'sublibrary', 'BARCODE', 'pcnt_mito', 'S_score', 'G2M_score', 'phase', 'pass_filter', 'cell_name', 'plate'
# 38 / 50 CVCL_0359 View of AnnData object with n_obs × n_vars = 153212 × 62710
#     obs: 'sample', 'gene_count', 'tscp_count', 'mread_count', 'drugname_drugconc', 'drug', 'cell_line', 'sublibrary', 'BARCODE', 'pcnt_mito', 'S_score', 'G2M_score', 'phase', 'pass_filter', 'cell_name', 'plate'
# 39 / 50 CVCL_1119 View of AnnData object with n_obs × n_vars = 142564 × 62710
#     obs: 'sample', 'gene_count', 'tscp_count', 'mread_count', 'drugname_drugconc', 'drug', 'cell_line', 'sublibrary', 'BARCODE', 'pcnt_mito', 'S_score', 'G2M_score', 'phase', 'pass_filter', 'cell_name', 'plate'
# 40 / 50 CVCL_1717 View of AnnData object with n_obs × n_vars = 151418 × 62710
#     obs: 'sample', 'gene_count', 'tscp_count', 'mread_count', 'drugname_drugconc', 'drug', 'cell_line', 'sublibrary', 'BARCODE', 'pcnt_mito', 'S_score', 'G2M_score', 'phase', 'pass_filter', 'cell_name', 'plate'
# 41 / 50 CVCL_0292 View of AnnData object with n_obs × n_vars = 96120 × 62710
#     obs: 'sample', 'gene_count', 'tscp_count', 'mread_count', 'drugname_drugconc', 'drug', 'cell_line', 'sublibrary', 'BARCODE', 'pcnt_mito', 'S_score', 'G2M_score', 'phase', 'pass_filter', 'cell_name', 'plate'
# 42 / 50 CVCL_0069 View of AnnData object with n_obs × n_vars = 89887 × 62710
#     obs: 'sample', 'gene_count', 'tscp_count', 'mread_count', 'drugname_drugconc', 'drug', 'cell_line', 'sublibrary', 'BARCODE', 'pcnt_mito', 'S_score', 'G2M_score', 'phase', 'pass_filter', 'cell_name', 'plate'
# 43 / 50 CVCL_1381 View of AnnData object with n_obs × n_vars = 123994 × 62710
#     obs: 'sample', 'gene_count', 'tscp_count', 'mread_count', 'drugname_drugconc', 'drug', 'cell_line', 'sublibrary', 'BARCODE', 'pcnt_mito', 'S_score', 'G2M_score', 'phase', 'pass_filter', 'cell_name', 'plate'
# 44 / 50 CVCL_1693 View of AnnData object with n_obs × n_vars = 79105 × 62710
#     obs: 'sample', 'gene_count', 'tscp_count', 'mread_count', 'drugname_drugconc', 'drug', 'cell_line', 'sublibrary', 'BARCODE', 'pcnt_mito', 'S_score', 'G2M_score', 'phase', 'pass_filter', 'cell_name', 'plate'
# 45 / 50 CVCL_0546 View of AnnData object with n_obs × n_vars = 405696 × 62710
#     obs: 'sample', 'gene_count', 'tscp_count', 'mread_count', 'drugname_drugconc', 'drug', 'cell_line', 'sublibrary', 'BARCODE', 'pcnt_mito', 'S_score', 'G2M_score', 'phase', 'pass_filter', 'cell_name', 'plate'
# 46 / 50 CVCL_1517 View of AnnData object with n_obs × n_vars = 192337 × 62710
#     obs: 'sample', 'gene_count', 'tscp_count', 'mread_count', 'drugname_drugconc', 'drug', 'cell_line', 'sublibrary', 'BARCODE', 'pcnt_mito', 'S_score', 'G2M_score', 'phase', 'pass_filter', 'cell_name', 'plate'
# 47 / 50 CVCL_1715 View of AnnData object with n_obs × n_vars = 17062 × 62710
#     obs: 'sample', 'gene_count', 'tscp_count', 'mread_count', 'drugname_drugconc', 'drug', 'cell_line', 'sublibrary', 'BARCODE', 'pcnt_mito', 'S_score', 'G2M_score', 'phase', 'pass_filter', 'cell_name', 'plate'
# 48 / 50 CVCL_1495 View of AnnData object with n_obs × n_vars = 113172 × 62710
#     obs: 'sample', 'gene_count', 'tscp_count', 'mread_count', 'drugname_drugconc', 'drug', 'cell_line', 'sublibrary', 'BARCODE', 'pcnt_mito', 'S_score', 'G2M_score', 'phase', 'pass_filter', 'cell_name', 'plate'
# 49 / 50 CVCL_1094 View of AnnData object with n_obs × n_vars = 88706 × 62710
#     obs: 'sample', 'gene_count', 'tscp_count', 'mread_count', 'drugname_drugconc', 'drug', 'cell_line', 'sublibrary', 'BARCODE', 'pcnt_mito', 'S_score', 'G2M_score', 'phase', 'pass_filter', 'cell_name', 'plate'

# %%
with fs.open("gs://tahoe100m-plate3-cvcl0023/"+plate+'_'+cell_line+'.h5ad', 'wb') as f:
    adata1.write(f,compression='gzip')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[17], line 2
#       1 with fs.open("gs://tahoe100m-plate3-cvcl0023/"+plate+'_'+cell_line+'.h5ad', 'wb') as f:
# ----> 2     adata1.write(f,compression='gzip')
#
# File ~/tahoe/lib/python3.11/site-packages/anndata/_core/anndata.py:1866, in AnnData.write_h5ad(self, filename, compression, compression_opts, as_dense)
#    1863     filename = self.filename
#    1865 write_h5ad(
# -> 1866     Path(filename),
#    1867     self,
#    1868     compression=compression,
#    1869     compression_opts=compression_opts,
#    1870     as_dense=as_dense,
#    1871 )
#    1873 if self.isbacked:
#
# File /usr/lib/python3.11/pathlib.py:872, in Path.__new__(cls, *args, **kwargs)
#     871     cls = WindowsPath if os.name == 'nt' else PosixPath
# --> 872 self = cls._from_parts(args)
#     873 if not self._flavour.is_supported:
#
# File /usr/lib/python3.11/pathlib.py:510, in PurePath._from_parts(cls, args)
#     509 self = object.__new__(cls)
# --> 510 drv, root, parts = self._parse_args(args)
#     511 self._drv = drv
#
# File /usr/lib/python3.11/pathlib.py:494, in PurePath._parse_args(cls, args)
#     493 else:
# --> 494     a = os.fspath(a)
#     495     if isinstance(a, str):
#     496         # Force-cast str subclasses to str (issue #21127)
#
# TypeError: expected str, bytes or os.PathLike object, not GCSFile
#
# During handling of the above exception, another exception occurred:
#
# OSError                                   Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 with fs.open("gs://tahoe100m-plate3-cvcl0023/"+plate+'_'+cell_line+'.h5ad', 'wb') as f:
#       2     adata1.write(f,compression='gzip')
#
# File ~/tahoe/lib/python3.11/site-packages/fsspec/spec.py:2227, in AbstractBufferedFile.__exit__(self, *args)
#    2226 def __exit__(self, *args):
# -> 2227     self.close()
#
# File ~/tahoe/lib/python3.11/site-packages/fsspec/spec.py:2178, in AbstractBufferedFile.close(self)
#    2176 else:
#    2177     if not self.forced:
# -> 2178         self.flush(force=True)
#    2180     if self.fs is not None:
#    2181         self.fs.invalidate_cache(self.path)
#
# File ~/tahoe/lib/python3.11/site-packages/fsspec/spec.py:2036, in AbstractBufferedFile.flush(self, force)
#    2034 self.offset = 0
#    2035 try:
# -> 2036     self._initiate_upload()
#    2037 except:
#    2038     self.closed = True
#
# File ~/tahoe/lib/python3.11/site-packages/gcsfs/core.py:1929, in GCSFile._initiate_upload(self)
#    1927 def _initiate_upload(self):
#    1928     """Create multi-upload"""
# -> 1929     self.location = asyn.sync(
#    1930         self.gcsfs.loop,
#    1931         initiate_upload,
#    1932         self.gcsfs,
#    1933         self.bucket,
#    1934         self.key,
#    1935         self.content_type,
#    1936         self.metadata,
#    1937         self.fixed_key_metadata,
#    1938         mode="create" if "x" in self.mode else "overwrite",
#    1939         timeout=self.timeout,
#    1940     )
#
# File ~/tahoe/lib/python3.11/site-packages/fsspec/asyn.py:103, in sync(loop, func, timeout, *args, **kwargs)
#     101     raise FSTimeoutError from return_result
#     102 elif isinstance(return_result, BaseException):
# --> 103     raise return_result
#     104 else:
#     105     return return_result
#
# File ~/tahoe/lib/python3.11/site-packages/fsspec/asyn.py:56, in _runner(event, coro, result, timeout)
#      54     coro = asyncio.wait_for(coro, timeout=timeout)
#      55 try:
# ---> 56     result[0] = await coro
#      57 except Exception as ex:
#      58     result[0] = ex
#
# File ~/tahoe/lib/python3.11/site-packages/gcsfs/core.py:2050, in initiate_upload(fs, bucket, key, content_type, metadata, fixed_key_metadata, mode)
#    2048 kw = {"ifGenerationMatch": "0"} if mode == "create" else {}
#    2049 j.update(_convert_fixed_key_metadata(fixed_key_metadata))
# -> 2050 headers, _ = await fs._call(
#    2051     method="POST",
#    2052     path=f"{fs._location}/upload/storage/v1/b/{quote(bucket)}/o?name={quote(key)}",
#    2053     uploadType="resumable",
#    2054     json=j,
#    2055     headers={"X-Upload-Content-Type": content_type},
#    2056     **kw,
#    2057 )
#    2058 loc = headers["Location"]
#    2059 out = loc[0] if isinstance(loc, list) else loc  # <- for CVR responses
#
# File ~/tahoe/lib/python3.11/site-packages/gcsfs/core.py:477, in GCSFileSystem._call(self, method, path, json_out, info_out, *args, **kwargs)
#     473 async def _call(
#     474     self, method, path, *args, json_out=False, info_out=False, **kwargs
#     475 ):
#     476     logger.debug(f"{method.upper()}: {path}, {args}, {kwargs.get('headers')}")
# --> 477     status, headers, info, contents = await self._request(
#     478         method, path, *args, **kwargs
#     479     )
#     480     if json_out:
#     481         return json.loads(contents)
#
# File ~/tahoe/lib/python3.11/site-packages/decorator.py:224, in decorate.<locals>.fun(*args, **kw)
#     222 if not kwsyntax:
#     223     args, kw = fix(args, kw, sig)
# --> 224 return await caller(func, *(extras + args), **kw)
#
# File ~/tahoe/lib/python3.11/site-packages/gcsfs/retry.py:135, in retry_request(func, retries, *args, **kwargs)
#     133     if retry > 0:
#     134         await asyncio.sleep(min(random.random() + 2 ** (retry - 1), 32))
# --> 135     return await func(*args, **kwargs)
#     136 except (
#     137     HttpError,
#     138     requests.exceptions.RequestException,
#    (...)    141     aiohttp.client_exceptions.ClientError,
#     142 ) as e:
#     143     if (
#     144         isinstance(e, HttpError)
#     145         and e.code == 400
#     146         and "requester pays" in e.message
#     147     ):
#
# File ~/tahoe/lib/python3.11/site-packages/gcsfs/core.py:470, in GCSFileSystem._request(self, method, path, headers, json, data, *args, **kwargs)
#     467 info = r.request_info  # for debug only
#     468 contents = await r.read()
# --> 470 validate_response(status, contents, path, args)
#     471 return status, headers, info, contents
#
# File ~/tahoe/lib/python3.11/site-packages/gcsfs/retry.py:114, in validate_response(status, content, path, args)
#     111     msg = content
#     113 if status == 403:
# --> 114     raise OSError(f"Forbidden: {path}\n{msg}")
#     115 elif status == 412:
#     116     raise FileExistsError(path)
#
# OSError: Forbidden: https://storage.googleapis.com/upload/storage/v1/b/tahoe100m-plate3-cvcl0023/o?name=plate3_CVCL_0023.h5ad
# Access denied.

# %%
##Downloading files
You can use gsutil to download any of the files in the bucket and work with them locally.

Please be considerate to the cost of egress when download the data from Google Cloud Storage.

For example:

gsutil cp gs://arc-ctc-tahoe100/2025-02-25/tutorial/plate3_2k-obs.h5ad .
For large data transfers, it is better to use gsutil rsync:

gsutil rsync gs://arc-ctc-tahoe100/2025-02-25/tutorial/ .
# Out:
#   Cell In[21], line 8
#     gsutil cp gs://arc-ctc-tahoe100/2025-02-25/tutorial/plate3_2k-obs.h5ad .
#                                          ^
# SyntaxError: leading zeros in decimal integer literals are not permitted; use an 0o prefix for octal integers
